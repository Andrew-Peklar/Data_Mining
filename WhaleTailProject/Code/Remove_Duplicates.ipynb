# %%
#   Source: https://www.kaggle.com/stehai/duplicate-images-data-cleaning
#   Modified by team Pepper
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import collections
import imagehash
from os import path as os_path

TRAIN_IMG_PATH = r"train/train"
###############################################################################
# misc functions

def plot_images(path, imgs):
    assert(isinstance(imgs, collections.Iterable))
    imgs_list = list(imgs)
    nrows = len(imgs_list)
    if (nrows % 2 != 0):
        nrows = nrows + 1 

    plt.figure(figsize=(18, 6*nrows/2))
    for i, img_file in enumerate(imgs_list):
        with Image.open(os_path.join(path, img_file)) as img:
            ax = plt.subplot(nrows/2, 2, i+1)
            ax.set_title("#{}: '{}'".format(i+1, img_file))
            ax.imshow(img)
        
    plt.show()


###############################################################################
# load data

def getImageMetaData(file_path):
    with Image.open(file_path) as img:
        img_hash = imagehash.phash(img)
        return img.size, img.mode, img_hash

def get_train_input():
    train_input = pd.read_csv(r"train.csv")
    
    m = train_input.Image.apply(lambda x: getImageMetaData(os_path.join(TRAIN_IMG_PATH, x)))
    train_input["Hash"] = [str(i[2]) for i in m]
    train_input["Shape"] = [i[0] for i in m]
    train_input["Mode"] = [str(i[1]) for i in m]
    train_input["Length"] = train_input["Shape"].apply(lambda x: x[0]*x[1])
    train_input["Ratio"] = train_input["Shape"].apply(lambda x: x[0]/x[1])
    train_input["New_Whale"] = train_input.Id == "new_whale"
    
    return train_input

train_input = get_train_input()

###############################################################################
# data cleaning duplicate images

# determine duplicate images using the hash

t = train_input.Hash.value_counts()
t = t[t > 1]
duplicates_df = pd.DataFrame(t)

# get the Ids of the duplicate images
duplicates_df["Ids"] =list(map(
            lambda x: set(train_input.Id[train_input.Hash==x].values), 
            t.index))
duplicates_df["Ids"] =list(map(
            lambda x: set(train_input.Id[train_input.Hash==x].values), 
            t.index))
duplicates_df["Ids_count"] = duplicates_df.Ids.apply(lambda x: len(x))
duplicates_df["Ids_contain_new_whale"] = duplicates_df.Ids.apply(lambda x: "new_whale" in x)

print(duplicates_df.head(20))

###
# There are 3 types of data errors regarding duplicate images:
#
# 1) The same image with the corresponding Id appears multiple time.
# 2) The same image appears with an Id and as "new_whale".
# 3) The same image appears with different Ids (ambiguous classified). 
#

# Fix error type 1: The same image with the corresponding Id appears multiple time.

train_input.drop_duplicates(["Hash", "Id"], inplace = True)

# Fix error type 2: The same image appears with an Id and as "new_whale".
# => delete the "new_whale" entry

drop_hash = duplicates_df.loc[(duplicates_df.Ids_count>1) & (duplicates_df.Ids_contain_new_whale==True)].index
train_input.drop(train_input.index[(train_input.Hash.isin(drop_hash) & (train_input.Id=="new_whale"))], inplace=True)

# Fix error type 3: The same image appears with different Ids (ambiguous classified).
# => delete all of them

drop_hash = duplicates_df.loc[(duplicates_df.Ids_count>1) & ((duplicates_df.Ids_count - duplicates_df.Ids_contain_new_whale)>1)].index

#print("Ambiguous classified images:")
#for i in drop_hash:
    #plot_images(TRAIN_IMG_PATH, 
                #train_input[train_input.Hash==i].Image)

train_input.drop(train_input.index[train_input.Hash.isin(drop_hash)], inplace=True)

# check if there are still duplicate images
assert(np.sum(train_input.Hash.value_counts()>1) == 0)
# Out:
#                   Hash                     Ids  Ids_count  \
# bb8ec43039cb663c     3  {w_cae7677, new_whale}          2
# 9e1bc5d0bc4e0bc3     2  {new_whale, w_7185713}          2
# af8fd0fcd3702940     2  {new_whale, w_1f09cdd}          2
# e9889673ed9d5a02     2  {new_whale, w_a365757}          2
# ee9ac1f47a4b8470     2  {new_whale, w_17a2610}          2
# ed088dab92f0e3f0     2  {new_whale, w_ab4cae2}          2
# 932c5ac3a4b9ac5b     2             {w_2f54c3c}          1
# 8b90a4633b5cd29f     2             {w_dcb1f2a}          1
# 84717a9ec1a4717d     2             {w_ee948c6}          1
# 96bd2dc2c8c272f4     2  {w_5ba417d, new_whale}          2
# e159966ab5455a8e     2             {w_9ff699b}          1
# a19886a5f9d8bc27     2             {w_5c6215c}          1
# afdad0b5c0ace928     2             {w_242a05d}          1
# f688cd27921d28d7     2             {w_f19faeb}          1
# e86a9296343dcbca     2             {w_05b2ddd}          1
# e990966279da8667     2             {w_09dd18c}          1
# da87a0689d7ace32     2             {w_19f0b15}          1
# ea9ec7a0f0adc8a4     2             {w_813c5be}          1
# accbd2b7a1a0a85d     2             {w_19a5685}          1
# bb07b06fc464d178     2             {w_1a5e7a2}          1
#
#                   Ids_contain_new_whale
# bb8ec43039cb663c                   True
# 9e1bc5d0bc4e0bc3                   True
# af8fd0fcd3702940                   True
# e9889673ed9d5a02                   True
# ee9ac1f47a4b8470                   True
# ed088dab92f0e3f0                   True
# 932c5ac3a4b9ac5b                  False
# 8b90a4633b5cd29f                  False
# 84717a9ec1a4717d                  False
# 96bd2dc2c8c272f4                   True
# e159966ab5455a8e                  False
# a19886a5f9d8bc27                  False
# afdad0b5c0ace928                  False
# f688cd27921d28d7                  False
# e86a9296343dcbca                  False
# e990966279da8667                  False
# da87a0689d7ace32                  False
# ea9ec7a0f0adc8a4                  False
# accbd2b7a1a0a85d                  False
# bb07b06fc464d178                  False

# %%
print("Ambiguous classified images:")
for i in drop_hash:
    plot_images(TRAIN_IMG_PATH, 
                train_input[train_input.Hash==i].Image)
# Out:
# Ambiguous classified images:

# %%
duplicates_df
# Out:
#                   Hash                     Ids  Ids_count  \
# bb8ec43039cb663c     3  {w_cae7677, new_whale}          2
# 9e1bc5d0bc4e0bc3     2  {new_whale, w_7185713}          2
# af8fd0fcd3702940     2  {new_whale, w_1f09cdd}          2
# e9889673ed9d5a02     2  {new_whale, w_a365757}          2
# ee9ac1f47a4b8470     2  {new_whale, w_17a2610}          2
# ed088dab92f0e3f0     2  {new_whale, w_ab4cae2}          2
# 932c5ac3a4b9ac5b     2             {w_2f54c3c}          1
# 8b90a4633b5cd29f     2             {w_dcb1f2a}          1
# 84717a9ec1a4717d     2             {w_ee948c6}          1
# 96bd2dc2c8c272f4     2  {w_5ba417d, new_whale}          2
# e159966ab5455a8e     2             {w_9ff699b}          1
# a19886a5f9d8bc27     2             {w_5c6215c}          1
# afdad0b5c0ace928     2             {w_242a05d}          1
# f688cd27921d28d7     2             {w_f19faeb}          1
# e86a9296343dcbca     2             {w_05b2ddd}          1
# e990966279da8667     2             {w_09dd18c}          1
# da87a0689d7ace32     2             {w_19f0b15}          1
# ea9ec7a0f0adc8a4     2             {w_813c5be}          1
# accbd2b7a1a0a85d     2             {w_19a5685}          1
# bb07b06fc464d178     2             {w_1a5e7a2}          1
# ea95f16a1dcb2690     2             {w_8d9c6fc}          1
# b64b97c031ed1a0f     2             {w_e3c1ec4}          1
# ba9e8760f89c0e63     2             {w_7c7a78c}          1
# bfcad0b524495e16     2  {new_whale, w_ea2385d}          2
# b0cccc31e3318fb9     2             {w_217e78a}          1
# 95ce2b64723e7231     2             {w_4a38a9f}          1
# bfc8d335a40c688f     2  {new_whale, w_c0f3e88}          2
# ba48c4b7c332f48d     2             {w_5e25f9f}          1
# e4895e7244a9f6f0     2             {w_2855124}          1
# afca90352dc85337     2             {w_01c2cb0}          1
# ...                ...                     ...        ...
# fa8e84e0b87d0dca     2  {new_whale, w_ee9c4d7}          2
# b48bcb7439daa621     2             {w_861cc1c}          1
# dac7b0689c298f2b     2             {w_41ed8e8}          1
# bbcad694c1b0e4b8     2  {new_whale, w_d62128e}          2
# ea1a858390e4f6e7     2  {new_whale, w_6361632}          2
# c81785e3b94eb61c     2             {w_8c1e2e4}          1
# eec0b52bf03d8b22     2             {w_9b401eb}          1
# de4580a2e578fa3a     2             {w_5d96ba4}          1
# c0363fcdba91368c     2             {w_5c62a56}          1
# ab9a857c570992c7     2  {w_741861e, w_b6efe77}          2
# be0ec2b4e7b22471     2  {new_whale, w_c9111ac}          2
# a06ada16e5677919     2             {w_13f8407}          1
# c6998a76a9fc21ca     2             {w_3e02970}          1
# bec394a1e03ccb1e     2             {w_ca94288}          1
# bd8887a26558eb72     2             {w_5f82501}          1
# a618d3a7a3345ccd     2             {w_d7de1ee}          1
# e93996c66731994a     2             {w_efebfe8}          1
# ea49c1b639a43ccd     2  {new_whale, w_c1b3568}          2
# e02d3c2a5e17479e     2             {w_143b201}          1
# bf0fc0f03c09da36     2             {w_3694c7d}          1
# 8ca6730ac3a4ec7b     2             {w_bf4880a}          1
# e6c19926e619799c     2             {w_f03ca16}          1
# ea9d84e2b169b9c8     2             {w_7e8b270}          1
# afd2b1fc286c1a43     2             {w_987a36f}          1
# be4fc2b6a7a1a0a4     2  {new_whale, w_b34793e}          2
# fd0e83e0e6e1e1e0     2             {w_4a78bf2}          1
# a5909a6ea78de8d4     2             {w_7311fe4}          1
# fa8ad2f42d4b880f     2             {w_f4e03d4}          1
# eb9481681bc7a17e     2             {w_637f363}          1
# bccb90a5ab6c491e     2             {w_def715a}          1
#
#                   Ids_contain_new_whale
# bb8ec43039cb663c                   True
# 9e1bc5d0bc4e0bc3                   True
# af8fd0fcd3702940                   True
# e9889673ed9d5a02                   True
# ee9ac1f47a4b8470                   True
# ed088dab92f0e3f0                   True
# 932c5ac3a4b9ac5b                  False
# 8b90a4633b5cd29f                  False
# 84717a9ec1a4717d                  False
# 96bd2dc2c8c272f4                   True
# e159966ab5455a8e                  False
# a19886a5f9d8bc27                  False
# afdad0b5c0ace928                  False
# f688cd27921d28d7                  False
# e86a9296343dcbca                  False
# e990966279da8667                  False
# da87a0689d7ace32                  False
# ea9ec7a0f0adc8a4                  False
# accbd2b7a1a0a85d                  False
# bb07b06fc464d178                  False
# ea95f16a1dcb2690                  False
# b64b97c031ed1a0f                  False
# ba9e8760f89c0e63                  False
# bfcad0b524495e16                   True
# b0cccc31e3318fb9                  False
# 95ce2b64723e7231                  False
# bfc8d335a40c688f                   True
# ba48c4b7c332f48d                  False
# e4895e7244a9f6f0                  False
# afca90352dc85337                  False
# ...                                 ...
# fa8e84e0b87d0dca                   True
# b48bcb7439daa621                  False
# dac7b0689c298f2b                  False
# bbcad694c1b0e4b8                   True
# ea1a858390e4f6e7                   True
# c81785e3b94eb61c                  False
# eec0b52bf03d8b22                  False
# de4580a2e578fa3a                  False
# c0363fcdba91368c                  False
# ab9a857c570992c7                  False
# be0ec2b4e7b22471                   True
# a06ada16e5677919                  False
# c6998a76a9fc21ca                  False
# bec394a1e03ccb1e                  False
# bd8887a26558eb72                  False
# a618d3a7a3345ccd                  False
# e93996c66731994a                  False
# ea49c1b639a43ccd                   True
# e02d3c2a5e17479e                  False
# bf0fc0f03c09da36                  False
# 8ca6730ac3a4ec7b                  False
# e6c19926e619799c                  False
# ea9d84e2b169b9c8                  False
# afd2b1fc286c1a43                  False
# be4fc2b6a7a1a0a4                   True
# fd0e83e0e6e1e1e0                  False
# a5909a6ea78de8d4                  False
# fa8ad2f42d4b880f                  False
# eb9481681bc7a17e                  False
# bccb90a5ab6c491e                  False
#
# [777 rows x 4 columns]

# %%
train_input
# Out:
#              Image         Id              Hash        Shape Mode  Length  \
# 0     00022e1a.jpg  w_e15442c  b362cc79b1a623b8   (699, 500)    L  349500
# 1     000466c4.jpg  w_1287fbc  b3cccc3331cc8733  (1050, 700)  RGB  735000
# 2     00087b01.jpg  w_da2efe0  bc4ed0f2a7e168a8  (1050, 368)  RGB  386400
# 3     001296d5.jpg  w_19e5482  93742d9a28b35b87   (397, 170)  RGB   67490
# 4     0014cfdf.jpg  w_f22f3e3  d4a1dab1c49f6352   (700, 398)    L  278600
# 5     0025e8c2.jpg  w_8b1ca89  ee1292c52c7bc627  (1000, 652)  RGB  652000
# 6     0026a8ab.jpg  w_eaad6a8  dacaa0f0bde91625  (1050, 317)  RGB  332850
# 8     0035632e.jpg  w_3d0bc7a  bb0ed0b6e5a1ac31   (843, 400)  RGB  337200
# 9     0037e7d3.jpg  w_50db782  b2cccd31f2c84ce3  (1050, 700)  RGB  735000
# 10    00389cd7.jpg  w_2863d51  fbc3a5782ec1c0c3  (1050, 600)  RGB  630000
# 11    0042dcc4.jpg  w_6dc7db6  bf9284ecc6e56b40  (1050, 367)  RGB  385350
# 12    0042ea34.jpg  w_968f2ca  e4d1996a96a5e958   (532, 228)  RGB  121296
# 13    00467ae9.jpg  w_fd1cb9d  face8521381e0fe3  (1000, 667)  RGB  667000
# 14    004a97f3.jpg  w_60759c2  bec0d338ce5a9724   (700, 410)    L  287000
# 15    004c5fb9.jpg  w_ab6bb0a  ebda94a7c23029ad  (1050, 422)  RGB  443100
# 16    005c57e7.jpg  w_79b42cd  a3508db3738c8c77   (831, 475)  RGB  394725
# 17    006d0aaf.jpg  w_c9ba30c  b580c9c3367c8d79  (1050, 700)  RGB  735000
# 18    0078af23.jpg  w_e6ec8ee  b94eccd897a5e130  (1050, 600)  RGB  630000
# 19    007c3603.jpg  new_whale  f39c8de3182c4bf0   (822, 471)    L  387162
# 21    008809b5.jpg  w_7e5cc5e  ae9695a3c768c0f8  (1050, 327)  RGB  343350
# 22    008baccf.jpg  w_ab6db0f  afd0f5328c2f432a  (1050, 316)  RGB  331800
# 23    0091c92b.jpg  w_bc8d634  f08f8f72322c4dc3  (1050, 683)  RGB  717150
# 24    009dca38.jpg  w_b59c523  a64bc296b5ec0ec5   (677, 247)  RGB  167219
# 25    00a29f63.jpg  w_2850471  afd2c535c81d1bc2  (1050, 367)  RGB  385350
# 26    00aa021c.jpg  new_whale  92e16d1f9ec560b1   (746, 497)  RGB  370762
# 27    00ab018e.jpg  w_51969d2  eb1e85e8f227e124  (1050, 327)  RGB  343350
# 28    00ac0e86.jpg  w_4be8a3e  b18881e2ea7669de  (1050, 525)  RGB  551250
# 29    00acb5a9.jpg  w_c0cfd5b  bc0dc3f2ae79188a   (571, 245)  RGB  139895
# 30    00ad9219.jpg  new_whale  e19ca2718d7a5e07  (1050, 288)  RGB  302400
# 31    00af84d8.jpg  w_339c8ae  ee988566581da5ea   (700, 500)    L  350000
# ...            ...        ...               ...          ...  ...     ...
# 9814  ff0de88a.jpg  w_18eee6e  ef9c90335a0d698e   (903, 516)  RGB  465948
# 9815  ff0df395.jpg  w_40a8760  97c025ead6655b19  (1050, 600)  RGB  630000
# 9817  ff2760bb.jpg  w_3c0bbac  da83a070da36fb0b   (568, 222)  RGB  126096
# 9818  ff2965ba.jpg  w_a4b6a86  e7989e671c19c2c6   (443, 253)  RGB  112079
# 9819  ff2c20cc.jpg  w_f6fb689  aecad3350d62c8d3  (1050, 506)  RGB  531300
# 9821  ff3509c0.jpg  w_8ba2066  aadf84641b5783a6  (1050, 600)  RGB  630000
# 9824  ff3f151f.jpg  w_9d5f5cc  de8ba1b07e0f82e4  (1050, 566)  RGB  594300
# 9825  ff421460.jpg  w_a16b600  ea9e9461689ea5e1  (1000, 652)  RGB  652000
# 9826  ff4bb3a4.jpg  w_2d99a0c  8fcaf5a068bc0b5a  (1050, 286)  RGB  300300
# 9828  ff6946b4.jpg  w_17ee910  bf07c02761d8789e  (1030, 404)  RGB  416120
# 9829  ff6c1a92.jpg  w_4f0676a  bfc8deb7a0680a58   (933, 533)  RGB  497289
# 9830  ff6d6894.jpg  w_b426ff3  f78994e2799d8624   (994, 548)    L  544712
# 9831  ff7247f6.jpg  w_41afa58  ea1a94a4e2b0fd2b  (1050, 600)  RGB  630000
# 9832  ff8b2ad0.jpg  w_0f20cbc  d984cef1b270bc2c  (1050, 291)  RGB  305550
# 9833  ff92447f.jpg  w_372ae75  9bc5b52d0bc2729c  (1050, 298)    L  312900
# 9834  ff9d60a3.jpg  w_eb0a6ed  b75c81a35ea458d3  (1050, 600)  RGB  630000
# 9835  ffa6b9ac.jpg  w_edf5f77  dfa26894a5b03ccd  (1050, 525)  RGB  551250
# 9836  ffa78ccc.jpg  w_89d9c03  e929878a3a365d6c  (1050, 450)  RGB  472500
# 9837  ffb71ac2.jpg  new_whale  e2999966e268d99a   (525, 301)  RGB  158025
# 9838  ffbaa734.jpg  w_a190b3b  bf85a4e249d076b4  (1050, 241)  RGB  253050
# 9839  ffbca206.jpg  w_73b26b7  ea9e85e0f46578c8  (1050, 397)  RGB  416850
# 9840  ffc0b437.jpg  w_ace8c54  fa8f91e4b665111c   (912, 371)  RGB  338352
# 9841  ffc6986f.jpg  w_fce6ab2  f34cccf326433c0d   (525, 301)  RGB  158025
# 9842  ffcfd124.jpg  w_41a260a  b336ccccf1b38603   (700, 500)    L  350000
# 9843  ffd01d82.jpg  w_6249155  b038cfc774781b89  (1050, 600)    L  630000
# 9844  ffd1e7aa.jpg  new_whale  aa3a1790b3a1aceb  (1050, 300)  RGB  315000
# 9845  ffe5c306.jpg  w_2ceab05  a8ccd73328cccdc3  (1004, 519)    L  521076
# 9846  ffeaa7a4.jpg  w_b067417  e1d89665989e6729  (1050, 792)  RGB  831600
# 9847  ffecec63.jpg  w_8b56cb1  aac8953f49d2ea32  (1050, 294)  RGB  308700
# 9849  fffd4260.jpg  w_b9bfd4e  85697a1e87a2f0e5   (521, 247)  RGB  128687
#
#          Ratio  New_Whale
# 0     1.398000      False
# 1     1.500000      False
# 2     2.853261      False
# 3     2.335294      False
# 4     1.758794      False
# 5     1.533742      False
# 6     3.312303      False
# 8     2.107500      False
# 9     1.500000      False
# 10    1.750000      False
# 11    2.861035      False
# 12    2.333333      False
# 13    1.499250      False
# 14    1.707317      False
# 15    2.488152      False
# 16    1.749474      False
# 17    1.500000      False
# 18    1.750000      False
# 19    1.745223       True
# 21    3.211009      False
# 22    3.322785      False
# 23    1.537335      False
# 24    2.740891      False
# 25    2.861035      False
# 26    1.501006       True
# 27    3.211009      False
# 28    2.000000      False
# 29    2.330612      False
# 30    3.645833       True
# 31    1.400000      False
# ...        ...        ...
# 9814  1.750000      False
# 9815  1.750000      False
# 9817  2.558559      False
# 9818  1.750988      False
# 9819  2.075099      False
# 9821  1.750000      False
# 9824  1.855124      False
# 9825  1.533742      False
# 9826  3.671329      False
# 9828  2.549505      False
# 9829  1.750469      False
# 9830  1.813869      False
# 9831  1.750000      False
# 9832  3.608247      False
# 9833  3.523490      False
# 9834  1.750000      False
# 9835  2.000000      False
# 9836  2.333333      False
# 9837  1.744186       True
# 9838  4.356846      False
# 9839  2.644836      False
# 9840  2.458221      False
# 9841  1.744186      False
# 9842  1.400000      False
# 9843  1.750000      False
# 9844  3.500000       True
# 9845  1.934489      False
# 9846  1.325758      False
# 9847  3.571429      False
# 9849  2.109312      False
#
# [9062 rows x 8 columns]

# %%
adf = adf.drop(['Length', 'Mode', 'Shape', 'New_Whale', 'Ratio', 'Hash'], axis = 1)

# %%
adf
# Out:
#              Image         Id
# 0     00022e1a.jpg  w_e15442c
# 1     000466c4.jpg  w_1287fbc
# 2     00087b01.jpg  w_da2efe0
# 3     001296d5.jpg  w_19e5482
# 4     0014cfdf.jpg  w_f22f3e3
# 5     0025e8c2.jpg  w_8b1ca89
# 6     0026a8ab.jpg  w_eaad6a8
# 8     0035632e.jpg  w_3d0bc7a
# 9     0037e7d3.jpg  w_50db782
# 10    00389cd7.jpg  w_2863d51
# 11    0042dcc4.jpg  w_6dc7db6
# 12    0042ea34.jpg  w_968f2ca
# 13    00467ae9.jpg  w_fd1cb9d
# 14    004a97f3.jpg  w_60759c2
# 15    004c5fb9.jpg  w_ab6bb0a
# 16    005c57e7.jpg  w_79b42cd
# 17    006d0aaf.jpg  w_c9ba30c
# 18    0078af23.jpg  w_e6ec8ee
# 21    008809b5.jpg  w_7e5cc5e
# 22    008baccf.jpg  w_ab6db0f
# 23    0091c92b.jpg  w_bc8d634
# 24    009dca38.jpg  w_b59c523
# 25    00a29f63.jpg  w_2850471
# 27    00ab018e.jpg  w_51969d2
# 28    00ac0e86.jpg  w_4be8a3e
# 29    00acb5a9.jpg  w_c0cfd5b
# 31    00af84d8.jpg  w_339c8ae
# 32    00b2c0cd.jpg  w_7c7a78c
# 33    00b588d6.jpg  w_25871da
# 34    00b7de10.jpg  w_97f5054
# ...            ...        ...
# 9811  fefc845c.jpg  w_dbda0d6
# 9813  ff0d2705.jpg  w_4e52a49
# 9814  ff0de88a.jpg  w_18eee6e
# 9815  ff0df395.jpg  w_40a8760
# 9817  ff2760bb.jpg  w_3c0bbac
# 9818  ff2965ba.jpg  w_a4b6a86
# 9819  ff2c20cc.jpg  w_f6fb689
# 9821  ff3509c0.jpg  w_8ba2066
# 9824  ff3f151f.jpg  w_9d5f5cc
# 9825  ff421460.jpg  w_a16b600
# 9826  ff4bb3a4.jpg  w_2d99a0c
# 9828  ff6946b4.jpg  w_17ee910
# 9829  ff6c1a92.jpg  w_4f0676a
# 9830  ff6d6894.jpg  w_b426ff3
# 9831  ff7247f6.jpg  w_41afa58
# 9832  ff8b2ad0.jpg  w_0f20cbc
# 9833  ff92447f.jpg  w_372ae75
# 9834  ff9d60a3.jpg  w_eb0a6ed
# 9835  ffa6b9ac.jpg  w_edf5f77
# 9836  ffa78ccc.jpg  w_89d9c03
# 9838  ffbaa734.jpg  w_a190b3b
# 9839  ffbca206.jpg  w_73b26b7
# 9840  ffc0b437.jpg  w_ace8c54
# 9841  ffc6986f.jpg  w_fce6ab2
# 9842  ffcfd124.jpg  w_41a260a
# 9843  ffd01d82.jpg  w_6249155
# 9845  ffe5c306.jpg  w_2ceab05
# 9846  ffeaa7a4.jpg  w_b067417
# 9847  ffecec63.jpg  w_8b56cb1
# 9849  fffd4260.jpg  w_b9bfd4e
#
# [8427 rows x 2 columns]

# %%
adf.to_csv('new.csv', sep='\t', encoding='ascii', index = False)
